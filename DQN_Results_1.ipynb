# %%
import numpy as np, pandas as pd, pickle
import matplotlib.pyplot as plt

# %%
with open('/home/ndg/users/dparek/rl_final_project_turtle/saved_stats/connect_dots_dqn.pkl', 'rb') as fin:
    data = pickle.load(fin)

# %%
connected = pd.Series(data['all_connected'])

# %%
connected.value_counts()
# Out:
# 0     23984
# 1     10167
# 2      6429
# 3      4231
# 4      2863
# 5      2181
# 6      1731
# 7      1131
# 8       741
# 9       353
# 10      140
# 11       41
# 12        9
# dtype: int64

# %%
connected.plot(figsize=(20,15))
plt.show()

# %%
x=connected.expanding().mean()
x.plot(figsize=(20,15))
plt.show()

# %%
rewards = pd.Series(data['rewards'])

# %%
rewards.plot(figsize=(20,15))
plt.show()

# %%
x=rewards.rolling(window=1000).mean()
x.plot(figsize=(20,15))
plt.show()

# %%
x=rewards.expanding().mean()
x.plot(figsize=(10,8), fontsize=15)
plt.show()

# %%
best_episode, best_reward, best_grids = data['best_grids']

# %%
best_episode, best_reward
# Out:
# (39561, -106.93903693170795)

# %%
plt.imshow(best_grids[20][0])
plt.show()

# %%
import imageio
from IPython.display import display, Image
import PIL

# %%
images = [
    (255*a[0]).astype(np.uint8)  
    for a in best_grids
]

# %%
images = [
    PIL.Image.fromarray(a).resize((280,280))
    for a in images
]

# %%
imageio.mimsave('dqn_training.gif', [np.asarray(a) for a in images], fps=24)

# %%
plt.imshow(best_grids[-1][0])
plt.show()

# %%
rewards.loc[connected[connected == 12].index]
# Out:
# 29610   -169.164026
# 29618   -165.316847
# 33791   -174.324911
# 34509   -218.129460
# 35615   -186.121099
# 38540   -166.555401
# 39561   -106.939037
# 40985   -212.744017
# 41470   -201.940834
# dtype: float64

# %%
timesteps = pd.Series(data['timesteps'])
all_grids = pd.Series(data['all_grids'])

# %%
timesteps.loc[connected[connected == 12].index]
# Out:
# 29610    2501
# 29618    2457
# 33791    2545
# 34509    2990
# 35615    2661
# 38540    2465
# 39561    1876
# 40985    2936
# 41470    2826
# dtype: int64

# %%
for i, v in all_grids.iteritems():
    ie, g = v
    if ie in connected[connected == 12].index:
        plt.imshow(g)
        plt.show()

# %%
pwd
# Out:
# '/home/ndg/users/dparek/notebooks/rl_project'
