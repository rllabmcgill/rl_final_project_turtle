# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
sys.path.append('%s/lib/pytorch-playground/'%os.path.abspath('.'))

# %%
from logo.connect_dots_env import *

# %%
env = ConnectDotsEnv(digit=3)

# %%
env.render()
# Out:
# Close:  False

# %%
env.set_state(row=6,col=6,direction=0)

# %%
env.turtle_pos
# Out:
# (6, 6, 0)

# %%
env.total_connected
# Out:
# 0

# %%
actions = []
actions.extend([TurtleActions.FD1]*15)
actions.append(TurtleActions.RT1)
actions.extend([TurtleActions.FD1]*7)
actions.append(TurtleActions.RT1)
actions.extend([TurtleActions.FD1]*10)
actions.append(TurtleActions.RT1)
actions.append(TurtleActions.RT1)
actions.extend([TurtleActions.FD1]*10)
actions.append(TurtleActions.RT1)
actions.extend([TurtleActions.FD1]*8)
actions.append(TurtleActions.RT1)
actions.extend([TurtleActions.FD1]*15)

# %%
for action in actions:
    a=env.step(action)
    print(a[1:])
    print(env.turtle_pos)
    env.render()
# Out:
# (-1.0, False, {})
# (6, 7, 0)
# Close:  False
# (-1.0, False, {})
# (6, 8, 0)
# Close:  False
# (-1.0, False, {})
# (6, 9, 0)
# Close:  False
# (-1.0, False, {})
# (6, 10, 0)
# Close:  False
# (1.0, False, {})
# (6, 11, 0)
# Close:  False
# (-1.0, False, {})
# (6, 12, 0)
# Close:  False
# (-1.0, False, {})
# (6, 13, 0)
# Close:  False
# (-1.0, False, {})
# (6, 14, 0)
# Close:  False
# (-1.0, False, {})
# (6, 15, 0)
# Close:  False
# (1.0, False, {})
# (6, 16, 0)
# Close:  False
# (-1.0, False, {})
# (6, 17, 0)
# Close:  False
# (-1.0, False, {})
# (6, 18, 0)
# Close:  False
# (-1.0, False, {})
# (6, 19, 0)
# Close:  False
# (-1.0, False, {})
# (6, 20, 0)
# Close:  False
# (1.0, False, {})
# (6, 21, 0)
# Close:  False
# (-1.0, False, {})
# (6, 21, 3)
# Close:  False
# (-1.0, False, {})
# (7, 21, 3)
# Close:  False
# (-1.0, False, {})
# (8, 21, 3)
# Close:  False
# (-1.0, False, {})
# (9, 21, 3)
# Close:  False
# (1.0, False, {})
# (10, 21, 3)
# Close:  False
# (-1.0, False, {})
# ...

# %% [markdown]
# actions_digit_3 = [TurtleActions.FD1]*15
# actions_digit_3.extend([TurtleActions.RT1]*2)
# actions_digit_3.extend([TurtleActions.FD1]*7)
# actions_digit_3.extend([TurtleActions.RT1]*2)
# actions_digit_3.extend([TurtleActions.FD1]*10)
# actions_digit_3.extend([TurtleActions.RT1]*4)
# actions_digit_3.extend([TurtleActions.FD0]*10)
# actions_digit_3.extend([TurtleActions.RT1]*2)
# actions_digit_3.extend([TurtleActions.FD1]*7)
# actions_digit_3.extend([TurtleActions.RT1]*2)
# actions_digit_3.extend([TurtleActions.FD1]*15)
# actions_digit_3.append(TurtleActions.STOP)

# %% [markdown]
# for action in actions_digit_3:
#     a=env.step(action)
#     print(a[1:])
#     print(env.turtle_pos)
#     env.render()

# %% [markdown]
# import pandas as pd

# %% [markdown]
# df1= pd.read_pickle('saved_stats/ddqn_rewards_steps_12k.pkl')

# %% [markdown]
# from IPython.display import display, HTML, clear_output
# import matplotlib.pyplot as plt

# %% [markdown]
# for row in df1.sort_values(by='rewards', ascending=False).itertuples():
#     clear_output()
#     print('episode: %s\nreward: %s\ntimestep: %s' % (row.Index, row.rewards, row.timesteps))
#     plt.imshow(row.grids, cmap='gray_r')
#     plt.show()
#     input()
