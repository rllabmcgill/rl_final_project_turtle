# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
sys.path.append('%s/lib/pytorch-playground/'%os.path.abspath('.'))

# %%
from logo.mnist_turtle_env import *

# %%
env = MnistTurtleEnv(digit=3)
# Out:
# Building and initializing mnist parameters
# Sequential(
#   (fc1): Linear(in_features=784, out_features=256, bias=True)
#   (relu1): ReLU()
#   (drop1): Dropout(p=0.2)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (relu2): ReLU()
#   (drop2): Dropout(p=0.2)
#   (out): Linear(in_features=256, out_features=10, bias=True)
# )
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
env.render()
# Out:
# Close:  False

# %%
env.set_state(row=5, col=5, direction=0, color=1)

# %%
actions_digit_3 = [TurtleActions.FD1]*15
actions_digit_3.extend([TurtleActions.RT1]*2)
actions_digit_3.extend([TurtleActions.FD1]*7)
actions_digit_3.extend([TurtleActions.RT1]*2)
actions_digit_3.extend([TurtleActions.FD1]*10)
actions_digit_3.extend([TurtleActions.RT1]*4)
actions_digit_3.extend([TurtleActions.FD0]*10)
actions_digit_3.extend([TurtleActions.RT1]*2)
actions_digit_3.extend([TurtleActions.FD1]*7)
actions_digit_3.extend([TurtleActions.RT1]*2)
actions_digit_3.extend([TurtleActions.FD1]*15)
actions_digit_3.append(TurtleActions.STOP)

# %%
for action in actions_digit_3:
    a=env.step(action)
    print(a[1:])
    print(env.turtle_pos)
    env.render()
# Out:
# (0.0026514993514865637, False, {'turtle_state': 2337})
# (5, 6, 0)
# Close:  False
# (0.03086811676621437, False, {'turtle_state': 2353})
# (5, 7, 0)
# Close:  False
# (0.002496233442798257, False, {'turtle_state': 2369})
# (5, 8, 0)
# Close:  False
# (0.011478140018880367, False, {'turtle_state': 2385})
# (5, 9, 0)
# Close:  False
# (0.011491684243083, False, {'turtle_state': 2401})
# (5, 10, 0)
# Close:  False
# (0.013413411565124989, False, {'turtle_state': 2417})
# (5, 11, 0)
# Close:  False
# (0.013821130618453026, False, {'turtle_state': 2433})
# (5, 12, 0)
# Close:  False
# (0.07642925530672073, False, {'turtle_state': 2449})
# (5, 13, 0)
# Close:  False
# (0.024190006777644157, False, {'turtle_state': 2465})
# (5, 14, 0)
# Close:  False
# (0.011380872689187527, False, {'turtle_state': 2481})
# (5, 15, 0)
# Close:  False
# (0.10513214766979218, False, {'turtle_state': 2497})
# (5, 16, 0)
# Close:  False
# (0.06429285556077957, False, {'turtle_state': 2513})
# (5, 17, 0)
# Close:  False
# (0.02323552966117859, False, {'turtle_state': 2529})
# (5, 18, 0)
# Close:  False
# (0.44041377305984497, False, {'turtle_state': 2545})
# (5, 19, 0)
# Close:  False
# (0.05830557644367218, False, {'turtle_state': 2561})
# (5, 20, 0)
# Close:  False
# (0.025443729013204575, False, {'turtle_state': 2575})
# (5, 20, 7)
# Close:  False
# (0.03646959364414215, False, {'turtle_state': 2573})
# (5, 20, 6)
# Close:  False
# (0.34022316336631775, False, {'turtle_state': 3021})
# (6, 20, 6)
# Close:  False
# (0.06765715777873993, False, {'turtle_state': 3469})
# (7, 20, 6)
# Close:  False
# (0.08393580466508865, False, {'turtle_state': 3917})
# (8, 20, 6)
# Close:  False
# (0.4388715326786041, False, {'turtle_state': 4365})
# (9, 20, 6)
# Close:  False
# (0.3271757960319519, False, {'turtle_state': 4813})
# (10, 20, 6)
# Close:  False
# (0.18714457750320435, False, {'turtle_state': 5261})
# (11, 20, 6)
# Close:  False
# (0.12154051661491394, False, {'turtle_state': 5709})
# (12, 20, 6)
# Close:  False
# (0.044153936207294464, False, {'turtle_state': 5707})
# (12, 20, 5)
# Close:  False
# (0.022505123168230057, False, {'turtle_state': 5705})
# (12, 20, 4)
# Close:  False
# (0.30795007944107056, False, {'turtle_state': 5689})
# (12, 19, 4)
# Close:  False
# (0.07336097210645676, False, {'turtle_state': 5673})
# (12, 18, 4)
# Close:  False
# (0.032213322818279266, False, {'turtle_state': 5657})
# (12, 17, 4)
# Close:  False
# (0.891339898109436, False, {'turtle_state': 5641})
# (12, 16, 4)
# Close:  False
# (0.04868881776928902, False, {'turtle_state': 5625})
# (12, 15, 4)
# Close:  False
# (0.1445162296295166, False, {'turtle_state': 5609})
# (12, 14, 4)
# Close:  False
# (0.8658558130264282, False, {'turtle_state': 5593})
# (12, 13, 4)
# Close:  False
# (0.6804722547531128, False, {'turtle_state': 5577})
# (12, 12, 4)
# Close:  False
# (0.7655475735664368, False, {'turtle_state': 5561})
# (12, 11, 4)
# Close:  False
# (0.9884082078933716, False, {'turtle_state': 5545})
# (12, 10, 4)
# Close:  False
# (0.9593774676322937, False, {'turtle_state': 5543})
# (12, 10, 3)
# Close:  False
# (0.9882344007492065, False, {'turtle_state': 5541})
# (12, 10, 2)
# Close:  False
# (0.9754026532173157, False, {'turtle_state': 5539})
# (12, 10, 1)
# Close:  False
# (0.9952237010002136, False, {'turtle_state': 5537})
# (12, 10, 0)
# Close:  False
# (0.9532004594802856, False, {'turtle_state': 5553})
# (12, 11, 0)
# Close:  False
# (0.5974634289741516, False, {'turtle_state': 5569})
# (12, 12, 0)
# Close:  False
# (0.9700321555137634, False, {'turtle_state': 5585})
# (12, 13, 0)
# Close:  False
# (0.9879388809204102, False, {'turtle_state': 5601})
# (12, 14, 0)
# Close:  False
# (0.9726338982582092, False, {'turtle_state': 5617})
# (12, 15, 0)
# Close:  False
# (0.9863993525505066, False, {'turtle_state': 5633})
# (12, 16, 0)
# Close:  False
# (0.9435615539550781, False, {'turtle_state': 5649})
# (12, 17, 0)
# Close:  False
# (0.5389490127563477, False, {'turtle_state': 5665})
# (12, 18, 0)
# Close:  False
# (0.9860596060752869, False, {'turtle_state': 5681})
# (12, 19, 0)
# Close:  False
# (0.9970508813858032, False, {'turtle_state': 5697})
# (12, 20, 0)
# Close:  False
# (0.9397318363189697, False, {'turtle_state': 5711})
# (12, 20, 7)
# Close:  False
# (0.9896436929702759, False, {'turtle_state': 5709})
# (12, 20, 6)
# Close:  False
# (0.1154417023062706, False, {'turtle_state': 6157})
# (13, 20, 6)
# Close:  False
# (0.6611826419830322, False, {'turtle_state': 6605})
# (14, 20, 6)
# Close:  False
# (0.852950394153595, False, {'turtle_state': 7053})
# (15, 20, 6)
# Close:  False
# (0.8097086548805237, False, {'turtle_state': 7501})
# (16, 20, 6)
# Close:  False
# (0.8760635256767273, False, {'turtle_state': 7949})
# (17, 20, 6)
# Close:  False
# (0.9738323092460632, False, {'turtle_state': 8397})
# (18, 20, 6)
# Close:  False
# (0.9875501990318298, False, {'turtle_state': 8845})
# (19, 20, 6)
# Close:  False
# (0.9436503052711487, False, {'turtle_state': 8843})
# (19, 20, 5)
# Close:  False
# (0.9920908808708191, False, {'turtle_state': 8841})
# (19, 20, 4)
# Close:  False
# (0.9646521806716919, False, {'turtle_state': 8825})
# (19, 19, 4)
# Close:  False
# (0.8613318204879761, False, {'turtle_state': 8809})
# (19, 18, 4)
# Close:  False
# (0.9854081273078918, False, {'turtle_state': 8793})
# (19, 17, 4)
# Close:  False
# (0.9466390013694763, False, {'turtle_state': 8777})
# (19, 16, 4)
# Close:  False
# (0.651441752910614, False, {'turtle_state': 8761})
# (19, 15, 4)
# Close:  False
# (0.6493470072746277, False, {'turtle_state': 8745})
# (19, 14, 4)
# Close:  False
# (0.9787733554840088, False, {'turtle_state': 8729})
# (19, 13, 4)
# Close:  False
# (0.8527000546455383, False, {'turtle_state': 8713})
# (19, 12, 4)
# Close:  False
# (0.9623278975486755, False, {'turtle_state': 8697})
# (19, 11, 4)
# Close:  False
# (0.9331358671188354, False, {'turtle_state': 8681})
# (19, 10, 4)
# Close:  False
# (0.9784475564956665, False, {'turtle_state': 8665})
# (19, 9, 4)
# Close:  False
# (0.9669334292411804, False, {'turtle_state': 8649})
# (19, 8, 4)
# Close:  False
# (0.9067238569259644, False, {'turtle_state': 8633})
# (19, 7, 4)
# Close:  False
# (0.9946823716163635, False, {'turtle_state': 8617})
# (19, 6, 4)
# Close:  False
# (0.932930588722229, False, {'turtle_state': 8601})
# (19, 5, 4)
# Close:  False
# (0.9969597458839417, True, {'turtle_state': 8601})
# (19, 5, 4)
# Close:  False
